# %%
import json
import pandas as pd

# %%
with open('test_dest.json', 'r') as fin:
    parsed_json = json.load(fin)

# %%
parsed_pd = pd.DataFrame(parsed_json)

# %%
parsed_pd.domain.unique().shape
# Out:
# (73,)

# %%
group_info = parsed_pd.groupby('domain').describe()

# %%
group_info['url']
# Out:
#                            count unique  \
# domain
# 24.kg                       1209   1209
# 7info.ru                      48     48
# agrovedomosti.ru              10     10
# aif.ru                       607    270
# aktualno.ru                   40     40
# ...                          ...    ...
# www.vedomosti.ru             413    400
# www.vesti.ru                  32     32
# www.zabinfo.ru               140     70
# xn--21-dlcie3di0l.xn--p1ai    20     20
# yarreg.ru                     40     20
#
#                                                                           top  \
# domain
# 24.kg                       https://24.kg/tsentralnaja_azija/40898_posle_s...
# 7info.ru                    https://7info.ru/v-dtp-s-uchastiem-avtomobilja...
# agrovedomosti.ru            http://agrovedomosti.ru/minczifry-predlozhilo-...
# aif.ru                      https://aif.ru/health/coronavirus/v_centre_im_...
# aktualno.ru                   https://aktualno.ru/view/sverdlovsk/afisha/5773
# ...                                                                       ...
# www.vedomosti.ru            https://www.vedomosti.ru/business/articles/202...
# www.vesti.ru                             https://www.vesti.ru/article/2643995
# www.zabinfo.ru                                       http://zabinfo.ru/163113
# xn--21-dlcie3di0l.xn--p1ai  http://xn--21-dlcie3di0l.xn--p1ai/2015/10/22/u...
# yarreg.ru                                            https://yarreg.ru/n5m5q/
#
#                            freq
# domain
# 24.kg                         1
# 7info.ru                      1
# agrovedomosti.ru              1
# aif.ru                        3
# aktualno.ru                   1
# ...                         ...
# www.vedomosti.ru              2
# www.vesti.ru                  1
# www.zabinfo.ru                2
# xn--21-dlcie3di0l.xn--p1ai    1
# yarreg.ru                     2
#
# [73 rows x 4 columns]

# %%
print(parsed_pd.columns[7])
group_info[parsed_pd.columns[7]]
# Out:
# category
#                            count unique                         top freq
# domain
# 24.kg                       1209     25                    Культура   50
# 7info.ru                      30     24  [Новости Рязани, Общество]    6
# agrovedomosti.ru              10      4                     Новости    4
# aif.ru                       270     54          Все о коронавирусе   31
# aktualno.ru                   40      6                    ��������   22
# ...                          ...    ...                         ...  ...
# www.vedomosti.ru             405     11                    Общество  107
# www.vesti.ru                  32      4                    общество   26
# www.zabinfo.ru               140     15           Политика и власть   22
# xn--21-dlcie3di0l.xn--p1ai    10      3                     НОВОСТИ    8
# yarreg.ru                     40      3                    Обществo   28
#
# [73 rows x 4 columns]

# %%
parsed_pd.columns
# Out:
# Index(['domain', 'url', 'author', 'title', 'description', 'pubDate', 'image',
#        'category', 'content', 'tags'],
#       dtype='object')

# %%
group_info['image']
# Out:
#                            count unique  \
# domain
# 24.kg                        113    113
# 7info.ru                       0      0
# agrovedomosti.ru               0      0
# aif.ru                       212    212
# aktualno.ru                   40     40
# ...                          ...    ...
# www.vedomosti.ru             400    387
# www.vesti.ru                  32     32
# www.zabinfo.ru                 0      0
# xn--21-dlcie3di0l.xn--p1ai     0      0
# yarreg.ru                     38     19
#
#                                                                           top  \
# domain
# 24.kg                                  https://24.kg/files/media/21/21188.jpg
# 7info.ru                                                                  NaN
# agrovedomosti.ru                                                          NaN
# aif.ru                      [https://aif-s3.aif.ru/images/025/867/9463b911...
# aktualno.ru                 https://aktualno.ru/images/content_news/22_Gla...
# ...                                                                       ...
# www.vedomosti.ru            https://cdn.vdmsti.ru/image/2021/93/1ejj6e/nor...
# www.vesti.ru                https://cdn-st1.rtr-vesti.ru/vh/pictures/b/327...
# www.zabinfo.ru                                                            NaN
# xn--21-dlcie3di0l.xn--p1ai                                                NaN
# yarreg.ru                   https://yarreg.ru/gallery/news/2021/11/261981/...
#
#                            freq
# domain
# 24.kg                         1
# 7info.ru                    NaN
# agrovedomosti.ru            NaN
# aif.ru                        1
# aktualno.ru                   1
# ...                         ...
# www.vedomosti.ru              2
# www.vesti.ru                  1
# www.zabinfo.ru              NaN
# xn--21-dlcie3di0l.xn--p1ai  NaN
# yarreg.ru                     2
#
# [73 rows x 4 columns]

# %%
group_info['content']
# Out:
#                            count unique  \
# domain
# 24.kg                          0      0
# 7info.ru                      48     48
# agrovedomosti.ru               0      0
# aif.ru                       270    270
# aktualno.ru                   40     40
# ...                          ...    ...
# www.vedomosti.ru               0      0
# www.vesti.ru                  32     32
# www.zabinfo.ru                 0      0
# xn--21-dlcie3di0l.xn--p1ai    20     20
# yarreg.ru                     40     20
#
#                                                                           top  \
# domain
# 24.kg                                                                     NaN
# 7info.ru                    \n<p>Пресс-служба «Одинцовской кондитерской фа...
# agrovedomosti.ru                                                          NaN
# aif.ru                      \n <p>Дочь народной артистки РФ Нины Русланово...
# aktualno.ru                 \n\t���������� �� ������� ������ ������ ������...
# ...                                                                       ...
# www.vedomosti.ru                                                          NaN
# www.vesti.ru                Музыкант Алишер Моргенштерн, по сути дела, тор...
# www.zabinfo.ru                                                            NaN
# xn--21-dlcie3di0l.xn--p1ai  <p>Цель всероссийской благотворительной акции ...
# yarreg.ru                   <p>На сайте &laquo;волонтер76.ру&raquo; опубли...
#
#                            freq
# domain
# 24.kg                       NaN
# 7info.ru                      1
# agrovedomosti.ru            NaN
# aif.ru                        1
# aktualno.ru                   1
# ...                         ...
# www.vedomosti.ru            NaN
# www.vesti.ru                  1
# www.zabinfo.ru              NaN
# xn--21-dlcie3di0l.xn--p1ai    1
# yarreg.ru                     2
#
# [73 rows x 4 columns]

# %%
all_tags = set()
for tags in parsed_pd['tags'].values:
    all_tags.update(tags)

# %%
all_tags
# Out:
# {'a',
#  'amplink',
#  'anons',
#  'author',
#  'category',
#  'commentRss',
#  'commenters',
#  'commenters24',
#  'comments',
#  'comments24',
#  'content',
#  'copyright',
#  'creator',
#  'credit',
#  'date',
#  'date.Taken',
#  'description',
#  'enclosure',
#  'encoded',
#  'explicit',
#  'full-text',
#  'genre',
#  'guid',
#  'image',
#  'img',
#  'is-comment',
#  'item',
#  'journal',
#  'link',
#  'links',
#  'links24',
#  'links24weight',
#  'linksweight',
#  'newsDate_timestamp',
#  'newsModifDate',
#  'news_id',
#  'newsline',
#  'pdalink',
#  'ppb_username',
#  'priority',
#  'pubDate',
#  'pubDateParsed',
#  'pubdate',
#  'published',
#  'related',
#  'related_links',
#  'reply-count',
#  'section',
#  'sections',
#  'security',
#  'size_nick',
#  'source',
#  'sport',
#  'summary',
#  'tag',
#  'tags',
#  'theme_tags',
#  'thumbnail',
#  'time',
#  'title',
#  'type',
#  'updated',
#  'url',
#  'video',
#  'visits24'}

# %%
tag = 'type'
parsed_pd[parsed_pd.tags.apply(lambda x: tag in x)].domain.unique()
# Out:
# array(['rssexport.rbc.ru', 'ria.ru'], dtype=object)

# %%
with open('smi2.json') as fin:
    smi_list = json.load(fin)

# %%
smi_list = [s['url'] for s in smi_list if s['url']]

# %%
with open('smi2.url', 'w') as fout:
    fout.write('\n'.join(smi_list))

# %%
with open('smi.url') as fin:
    top_list = [url.strip() for url in fin.readlines()]

# %%
smi_list = set(smi_list)

# %%
top_list = set(top_list)

# %%
top_list.update(smi_list)

# %%
with open('smi.url', 'w') as fout:
    fout.write('\n'.join(top_list))
